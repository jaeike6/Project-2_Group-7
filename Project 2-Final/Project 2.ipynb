# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
salary_df=pd.read_csv("../resources/nba_salary_final.csv")
salary_df= salary_df[["player_name","salary"]]
salary_df
# Out:
#         player_name      salary
# 0     Stephen Curry  34682550.0
# 1      LeBron James  33285709.0
# 2      Paul Millsap  31269231.0
# 3    Gordon Hayward  29727900.0
# 4     Blake Griffin  29512900.0
# ..              ...         ...
# 568      Quinn Cook     25000.0
# 569   Chris Johnson     25000.0
# 570      Beno Udrih     25000.0
# 571   Joel Bolomboy     22248.0
# 572    Jarell Eddie     17224.0
#
# [573 rows x 2 columns]

# %%
stats_df=pd.read_csv("../resources/nba_stats_final.csv")
stats_df
# Out:
#         player_name  age  minutes_played  field_goal_success  goal_success_3p  \
# 0      Aaron Brooks   33           189.0               0.406            0.355
# 1      Aaron Gordon   22          1909.0               0.434            0.336
# 2    Aaron Harrison   23           233.0               0.275            0.209
# 3     Aaron Jackson   31            35.0               0.333            0.250
# 4       Abdel Nader   24           522.0               0.336            0.354
# ..              ...  ...             ...                 ...              ...
# 461    Zach Collins   20          1045.0               0.398            0.310
# 462     Zach LaVine   22           656.0               0.383            0.341
# 463   Zach Randolph   36          1508.0               0.473            0.347
# 464   Zaza Pachulia   33           972.0               0.564            0.000
# 465         Zhou Qi   22           124.0               0.188            0.105
#
# ...

# %%
db_connection="postgres:postgres@localhost:5432/Project2_db"
engine=create_engine(f"postgresql://{db_connection}")

# %%
stats_df.to_sql(name="nba_stats",con=engine,index=False,if_exists="append")

# %%
salary_df.to_sql(name="nba_salary",con=engine,index=False,if_exists="append")

# %%
Team_df=pd.read_csv("../resources/Team.csv")
Team_df
# Out:
#    team  win_loss  finish
# 0   BOS     0.744       1
# 1   TOR     0.706       2
# 2   NYK     0.486       3
# 3   PHI     0.441       4
# 4   BRK     0.371       5
# 5   MIN     0.611       1
# 6   OKC     0.556       2
# 7   DEN     0.543       3
# 8   POR     0.529       4
# 9   UTA     0.417       5
# 10  CLE     0.686       1
# 11  DET     0.559       2
# 12  MIL     0.559       2
# 13  IND     0.528       4
# 14  CHI     0.371       5
# 15  GSW     0.778       1
# 16  LAC     0.441       2
# 17  PHO     0.378       3
# 18  SAC     0.343       4
# 19  LAL     0.324       5
# 20  WAS     0.556       1
# 21  MIA     0.514       2
# 22  CHO     0.371       3
# 23  ORL     0.333       4
# 24  ATL     0.257       5
# 25  HOU     0.735       1
# 26  SAS     0.694       2
# 27  NOP     0.514       3
# 28  DAL     0.324       4
# 29  MEM     0.314       5

# %%
Team_df.to_sql(name="team_stats",con=engine,index=False,if_exists="append")

# %%
engine.dispose()
