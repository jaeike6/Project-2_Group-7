# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# extract CSVs into DataFrames (NBA statistics)
nba_stats_path = "Resources/nba_extra.csv"
nba_stats_df = pd.read_csv(nba_stats_path)
nba_stats_df.head()
# Out:
#    Rk                   Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 0   1   Alex Abrines/abrinal01  SG   24  OKC  75   8  1134  115  291  ...
# 1   2       Quincy Acy/acyqu01  PF   27  BRK  70   8  1359  130  365  ...
# 2   3   Steven Adams/adamsst01   C   24  OKC  76  76  2487  448  712  ...
# 3   4    Bam Adebayo/adebaba01   C   20  MIA  69  19  1368  174  340  ...
# 4   5  Arron Afflalo/afflaar01  SG   32  ORL  53   3   682   65  162  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.848   26   88  114   28   38    8   25  124   353
# 1  0.817   40  217  257   57   33   29   60  149   411
# 2  0.559  384  301  685   88   92   78  128  215  1056
# 3  0.721  118  263  381  101   32   41   66  138   477
# 4  0.846    4   62   66   30    4    9   21   56   179
#
# [5 rows x 30 columns]

# %%
# transformation 1 : drop null value columns to advoid errors
nba_stats_df.dropna(inplace = True)

# %%
# transformation 2 : split player name and remove
nba_stats_df[['Player_name','Player_name_2']]=nba_stats_df['Player'].str.split("/",expand=True)
nba_stats_df
# Out:
#       Rk                   Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 0      1   Alex Abrines/abrinal01  SG   24  OKC  75   8  1134  115  291  ...
# 1      2       Quincy Acy/acyqu01  PF   27  BRK  70   8  1359  130  365  ...
# 2      3   Steven Adams/adamsst01   C   24  OKC  76  76  2487  448  712  ...
# 3      4    Bam Adebayo/adebaba01   C   20  MIA  69  19  1368  174  340  ...
# 4      5  Arron Afflalo/afflaar01  SG   32  ORL  53   3   682   65  162  ...
# ..   ...                      ...  ..  ...  ...  ..  ..   ...  ...  ...  ...
# 658  537   Tyler Zeller/zellety01   C   28  TOT  66  34  1109  187  334  ...
# 659  537   Tyler Zeller/zellety01   C   28  BRK  42  33   703  125  229  ...
# 660  537   Tyler Zeller/zellety01   C   28  MIL  24   1   406   62  105  ...
# 661  538    Paul Zipser/zipsepa01  SF   23  CHI  54  12   824   81  234  ...
# 663  540    Ivica Zubac/zubaciv01   C   20  LAL  43   0   410   61  122  ...
#
#      DRB  TRB  AST  STL  BLK  TOV   PF   PTS    Player_name  Player_name_2
# 0     88  114   28   38    8   25  124   353   Alex Abrines      abrinal01
# 1    217  257   57   33   29   60  149   411     Quincy Acy        acyqu01
# 2    301  685   88   92   78  128  215  1056   Steven Adams      adamsst01
# 3    263  381  101   32   41   66  138   477    Bam Adebayo      adebaba01
# 4     62   66   30    4    9   21   56   179  Arron Afflalo      afflaar01
# ..   ...  ...  ...  ...  ...  ...  ...   ...            ...            ...
# 658  195  305   47   15   35   47  126   441   Tyler Zeller      zellety01
# 659  131  194   28    8   21   35   78   300   Tyler Zeller      zellety01
# 660   64  111   19    7   14   12   48   141   Tyler Zeller      zellety01
# 661  118  131   46   20   15   43   86   218    Paul Zipser      zipsepa01
# 663   78  123   25    8   15   26   47   161    Ivica Zubac      zubaciv01
#
# [561 rows x 32 columns]

# %%
# transformation 3 : sort out necessary columns
nba_stats_selection = ["Player_name","Age","MP","FG%","3P%","2P%","eFG%","TRB","AST","STL","BLK","PTS"]
nba_stats_transformed_df = nba_stats_df[nba_stats_selection].copy()
nba_stats_transformed_df
# Out:
#        Player_name  Age    MP    FG%    3P%    2P%   eFG%  TRB  AST  STL  BLK  \
# 0     Alex Abrines   24  1134  0.395  0.380  0.443  0.540  114   28   38    8
# 1       Quincy Acy   27  1359  0.356  0.349  0.384  0.496  257   57   33   29
# 2     Steven Adams   24  2487  0.629  0.000  0.631  0.629  685   88   92   78
# 3      Bam Adebayo   20  1368  0.512  0.000  0.523  0.512  381  101   32   41
# 4    Arron Afflalo   32   682  0.401  0.386  0.413  0.485   66   30    4    9
# ..             ...  ...   ...    ...    ...    ...    ...  ...  ...  ...  ...
# 658   Tyler Zeller   28  1109  0.560  0.357  0.578  0.575  305   47   15   35
# 659   Tyler Zeller   28   703  0.546  0.385  0.567  0.568  194   28    8   21
# 660   Tyler Zeller   28   406  0.590  0.000  0.602  0.590  111   19    7   14
# 661    Paul Zipser   23   824  0.346  0.336  0.355  0.425  131   46   20   15
# 663    Ivica Zubac   20   410  0.500  0.000  0.504  0.500  123   25    8   15
#
#       PTS
# 0     353
# 1     411
# 2    1056
# 3     477
# 4     179
# ..    ...
# 658   441
# 659   300
# 660   141
# 661   218
# 663   161
#
# [561 rows x 12 columns]

# %%
# transformation 4 : remove duplicate
nba_stats_groupby = nba_stats_transformed_df.groupby(['Player_name'])
nba_stats_final = nba_stats_groupby.mean()
nba_stats_final
# Out:
#                  Age      MP    FG%    3P%    2P%   eFG%    TRB    AST   STL  \
# Player_name
# Aaron Brooks    33.0   189.0  0.406  0.355  0.447  0.486   17.0   20.0   6.0
# Aaron Gordon    22.0  1909.0  0.434  0.336  0.497  0.500  457.0  136.0  59.0
# Aaron Harrison  23.0   233.0  0.275  0.209  0.385  0.341   24.0   11.0   9.0
# Aaron Jackson   31.0    35.0  0.333  0.250  0.400  0.389    3.0    1.0   0.0
# Abdel Nader     24.0   522.0  0.336  0.354  0.321  0.413   71.0   26.0  15.0
# ...              ...     ...    ...    ...    ...    ...    ...    ...   ...
# Zach Collins    20.0  1045.0  0.398  0.310  0.455  0.458  221.0   52.0  17.0
# Zach LaVine     22.0   656.0  0.383  0.341  0.405  0.442   94.0   72.0  24.0
# Zach Randolph   36.0  1508.0  0.473  0.347  0.503  0.507  397.0  127.0  42.0
# Zaza Pachulia   33.0   972.0  0.564  0.000  0.567  0.564  321.0  109.0  38.0
# Zhou Qi         22.0   124.0  0.188  0.105  0.308  0.219   22.0    2.0   2.0
#
#                  BLK     PTS
# Player_name
# Aaron Brooks     0.0    75.0
# Aaron Gordon    45.0  1022.0
# Aaron Harrison   2.0    60.0
# Aaron Jackson    0.0     8.0
# Abdel Nader     10.0   146.0
# ...              ...     ...
# Zach Collins    31.0   292.0
# Zach LaVine      4.0   401.0
# Zach Randolph   10.0   857.0
# Zaza Pachulia   17.0   373.0
# Zhou Qi         14.0    22.0
#
# [466 rows x 11 columns]

# %%
# transformation 5 : rename the column headers

nba_stats_final = nba_stats_final.rename(columns={"MP": "minutes_played",
                                                  "FG%": "field_goal_success",
                                                  "3P%": "goal_success_3P",
                                                  "2P%": "goal_success_2P",
                                                  "eFG%":"effective_field_goal",
                                                  "TRB": "total_rebounds",
                                                  "AST": "assist",
                                                  "STL": "steal",
                                                  "BLK": "blocking",
                                                  "PTS": "points"
                                                 })
nba_stats_final
# Out:
#                  Age  minutes_played  field_goal_success  goal_success_3P  \
# Player_name
# Aaron Brooks    33.0           189.0               0.406            0.355
# Aaron Gordon    22.0          1909.0               0.434            0.336
# Aaron Harrison  23.0           233.0               0.275            0.209
# Aaron Jackson   31.0            35.0               0.333            0.250
# Abdel Nader     24.0           522.0               0.336            0.354
# ...              ...             ...                 ...              ...
# Zach Collins    20.0          1045.0               0.398            0.310
# Zach LaVine     22.0           656.0               0.383            0.341
# Zach Randolph   36.0          1508.0               0.473            0.347
# Zaza Pachulia   33.0           972.0               0.564            0.000
# Zhou Qi         22.0           124.0               0.188            0.105
#
#                 goal_success_2P  effective_field_goal  total_rebounds  assist  \
# Player_name
# Aaron Brooks              0.447                 0.486            17.0    20.0
# Aaron Gordon              0.497                 0.500           457.0   136.0
# Aaron Harrison            0.385                 0.341            24.0    11.0
# Aaron Jackson             0.400                 0.389             3.0     1.0
# Abdel Nader               0.321                 0.413            71.0    26.0
# ...                         ...                   ...             ...     ...
# Zach Collins              0.455                 0.458           221.0    52.0
# Zach LaVine               0.405                 0.442            94.0    72.0
# Zach Randolph             0.503                 0.507           397.0   127.0
# Zaza Pachulia             0.567                 0.564           321.0   109.0
# Zhou Qi                   0.308                 0.219            22.0     2.0
#
#                 steal  blocking  points
# Player_name
# Aaron Brooks      6.0       0.0    75.0
# Aaron Gordon     59.0      45.0  1022.0
# Aaron Harrison    9.0       2.0    60.0
# Aaron Jackson     0.0       0.0     8.0
# Abdel Nader      15.0      10.0   146.0
# ...               ...       ...     ...
# Zach Collins     17.0      31.0   292.0
# Zach LaVine      24.0       4.0   401.0
# Zach Randolph    42.0      10.0   857.0
# Zaza Pachulia    38.0      17.0   373.0
# Zhou Qi           2.0      14.0    22.0
#
# [466 rows x 11 columns]

# %%
# extract CSVs into DataFrames (NBA salary)
nba_salary_path = "Resources/NBA_season1718_salary.csv"
nba_salary_df = pd.read_csv(nba_salary_path)
nba_salary_df
# Out:
#      Unnamed: 0          Player   Tm  season17_18
# 0             1   Stephen Curry  GSW   34682550.0
# 1             2    LeBron James  CLE   33285709.0
# 2             3    Paul Millsap  DEN   31269231.0
# 3             4  Gordon Hayward  BOS   29727900.0
# 4             5   Blake Griffin  DET   29512900.0
# ..          ...             ...  ...          ...
# 568         569      Quinn Cook  NOP      25000.0
# 569         570   Chris Johnson  HOU      25000.0
# 570         571      Beno Udrih  DET      25000.0
# 571         572   Joel Bolomboy  MIL      22248.0
# 572         573    Jarell Eddie  CHI      17224.0
#
# [573 rows x 4 columns]

# %%
# transformation 1 : drop null value columns to advoid errors
nba_salary_df.dropna(inplace = True)

# %%
# transformation 2 : sort out necessary columns
nba_salary_selection = ["Player","season17_18"]
nba_salary_transformed_df = nba_salary_df[nba_salary_selection].copy()
nba_salary_transformed_df
# Out:
#              Player  season17_18
# 0     Stephen Curry   34682550.0
# 1      LeBron James   33285709.0
# 2      Paul Millsap   31269231.0
# 3    Gordon Hayward   29727900.0
# 4     Blake Griffin   29512900.0
# ..              ...          ...
# 568      Quinn Cook      25000.0
# 569   Chris Johnson      25000.0
# 570      Beno Udrih      25000.0
# 571   Joel Bolomboy      22248.0
# 572    Jarell Eddie      17224.0
#
# [573 rows x 2 columns]

# %%
# transformation 3 : rename the column headers

nba_salary_final = nba_salary_transformed_df.rename(columns={"Player": "Player_name",
                                                  "season17_18": "Salary"
                                                 })
nba_salary_final
# Out:
#         Player_name      Salary
# 0     Stephen Curry  34682550.0
# 1      LeBron James  33285709.0
# 2      Paul Millsap  31269231.0
# 3    Gordon Hayward  29727900.0
# 4     Blake Griffin  29512900.0
# ..              ...         ...
# 568      Quinn Cook     25000.0
# 569   Chris Johnson     25000.0
# 570      Beno Udrih     25000.0
# 571   Joel Bolomboy     22248.0
# 572    Jarell Eddie     17224.0
#
# [573 rows x 2 columns]

# %%
connection_string = "postgres:postgres@127.0.0.1:3475/customer_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# <ipython-input-188-d72bc75a6b62>:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#
# ~\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#
# OperationalError: could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "127.0.0.1" and accepting
# 	TCP/IP connections on port 3475?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-188-d72bc75a6b62> in <module>
# ----> 1 engine.table_names()
#
# <string> in table_names(self, schema, connection)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     388         if not skip_warning:
#     389             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 390         return fn(*args, **kwargs)
#     391
#     392     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    3109         :param connection: Optional, use a specified connection.
#    3110         """
# -> 3111         with self._optional_conn_ctx_manager(connection) as conn:
#    3112             insp = inspection.inspect(conn)
#    3113             return insp.get_table_names(schema)
#
# ~\Anaconda3\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2857     def _optional_conn_ctx_manager(self, connection=None):
#    2858         if connection is None:
# -> 2859             with self.connect() as conn:
#    2860                 yield conn
#    2861         else:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3093         """
#    3094
# -> 3095         return self._connection_cls(self, close_with_result=close_with_result)
#    3096
#    3097     @util.deprecated(
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      89                 connection
#      90                 if connection is not None
# ---> 91                 else engine.raw_connection()
#      92             )
#      93
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3172
#    3173         """
# -> 3174         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3175
#    3176
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3142         except dialect.dbapi.Error as e:
#    3143             if connection is None:
# -> 3144                 Connection._handle_dbapi_exception_noconnection(
#    3145                     e, dialect, self
#    3146                 )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2001             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2002         elif should_wrap:
# -> 2003             util.raise_(
#    2004                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2005             )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3139         dialect = self.dialect
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#    3143             if connection is None:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     299
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#     303     def _return_conn(self, record):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     753     def _checkout(cls, pool, threadconns=None, fairy=None):
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#     757             fairy._pool = pool
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     417     @classmethod
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#     421             dbapi_connection = rec.get_connection()
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     143             except:
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#     147             return self._do_get()
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     140         if self._inc_overflow():
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#     144                 with util.safe_reraise():
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     245         """Called by subclasses to create a new ConnectionRecord."""
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#     249     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     360         self.__pool = pool
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#     364
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     603         except Exception as e:
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#     607             if first_connect_check:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     597         try:
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#     601             self.connection = connection
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     557     def connect(self, *cargs, **cparams):
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#     561     def create_connect_args(self, url):
#
# ~\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "127.0.0.1" and accepting
# 	TCP/IP connections on port 3475?
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
